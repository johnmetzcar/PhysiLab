# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np  
import sys

# %%
df = pd.read_csv('../dataframes/aggregated_live_cells.csv', index_col=0)
df.head()
# Out:
#                        0.0  12.0  24.0  36.0  48.0  60.0  72.0  84.0  96.0  \
# intervention
# EG_Ceramide_S1P_1_11  1500  1500  1501  1501  1502  1503  1507  1509  1511
# EG_Ceramide_S1P_1_12  1500  1500  1502  1503  1505  1508  1511  1511  1512
# EG_Ceramide_S1P_1_13  1500  1502  1503  1503  1503  1505  1506  1507  1509
# EG_Ceramide_S1P_1_21  1500  1503  1505  1506  1506  1510  1511  1513  1514
# EG_Ceramide_S1P_1_22  1500  1501  1502  1502  1504  1507  1508  1513  1513
#
#                       108.0  ...  7812.0  7824.0  7836.0  7848.0  7860.0  \
# intervention                 ...
# EG_Ceramide_S1P_1_11   1513  ...     346     343     343     341     340
# EG_Ceramide_S1P_1_12   1512  ...     360     359     356     356     355
# EG_Ceramide_S1P_1_13   1510  ...     341     339     336     335     334
# EG_Ceramide_S1P_1_21   1516  ...       2       2       2       2       2
# EG_Ceramide_S1P_1_22   1513  ...       4       4       4       4       4
#
#                       7872.0  7884.0  7896.0  7908.0  7920.0
# intervention
# EG_Ceramide_S1P_1_11     341     341     340     340     340
# EG_Ceramide_S1P_1_12     354     354     354     353     353
# EG_Ceramide_S1P_1_13     334     334     334     333     331
# EG_Ceramide_S1P_1_21       2       2       2       2       2
# EG_Ceramide_S1P_1_22       4       4       4       4       4
#
# [5 rows x 661 columns]

# %%
df.iloc[:0]
# Out:
# Empty DataFrame
# Columns: [0.0, 12.0, 24.0, 36.0, 48.0, 60.0, 72.0, 84.0, 96.0, 108.0, 120.0, 132.0, 144.0, 156.0, 168.0, 180.0, 192.0, 204.0, 216.0, 228.0, 240.0, 252.0, 264.0, 276.0, 288.0, 300.0, 312.0, 324.0, 336.0, 348.0, 360.0, 372.0, 384.0, 396.0, 408.0, 420.0, 432.0, 444.0, 456.0, 468.0, 480.0, 492.0, 504.0, 516.0, 528.0, 540.0, 552.0, 564.0, 576.0, 588.0, 600.0, 612.0, 624.0, 636.0, 648.0, 660.0, 672.0, 684.0, 696.0, 708.0, 720.0, 732.0, 744.0, 756.0, 768.0, 780.0, 792.0, 804.0, 816.0, 828.0, 840.0, 852.0, 864.0, 876.0, 888.0, 900.0, 912.0, 924.0, 936.0, 948.0, 960.0, 972.0, 984.0, 996.0, 1008.0, 1020.0, 1032.0, 1044.0, 1056.0, 1068.0, 1080.0, 1092.0, 1104.0, 1116.0, 1128.0, 1140.0, 1152.0, 1164.0, 1176.0, 1188.0, ...]
# Index: []
#
# [0 rows x 661 columns]

# %%
df_transpose = df.transpose()
df_transpose.head(100)
# Out:
# intervention  EG_Ceramide_S1P_1_11  EG_Ceramide_S1P_1_12  \
# 0.0                           1500                  1500
# 12.0                          1500                  1500
# 24.0                          1501                  1502
# 36.0                          1501                  1503
# 48.0                          1502                  1505
# ...                            ...                   ...
# 1140.0                        1380                  1352
# 1152.0                        1382                  1348
# 1164.0                        1382                  1343
# 1176.0                        1382                  1342
# 1188.0                        1382                  1342
#
# intervention  EG_Ceramide_S1P_1_13  EG_Ceramide_S1P_1_21  \
# 0.0                           1500                  1500
# 12.0                          1502                  1503
# 24.0                          1503                  1505
# 36.0                          1503                  1506
# 48.0                          1503                  1506
# ...                            ...                   ...
# 1140.0                        1341                   812
# 1152.0                        1340                   804
# 1164.0                        1338                   799
# 1176.0                        1333                   791
# 1188.0                        1327                   781
#
# intervention  EG_Ceramide_S1P_1_22  EG_Ceramide_S1P_1_23  \
# 0.0                           1500                  1500
# 12.0                          1501                  1502
# 24.0                          1502                  1503
# 36.0                          1502                  1506
# 48.0                          1504                  1507
# ...                            ...                   ...
# 1140.0                         812                   776
# 1152.0                         807                   773
# 1164.0                         802                   764
# 1176.0                         798                   752
# 1188.0                         793                   744
#
# intervention  EG_Ceramide_S1P_1_31  EG_Ceramide_S1P_1_32  \
# 0.0                           1500                  1500
# 12.0                          1501                  1501
# 24.0                          1502                  1502
# 36.0                          1503                  1504
# 48.0                          1506                  1504
# ...                            ...                   ...
# 1140.0                         761                   761
# 1152.0                         752                   746
# 1164.0                         744                   727
# 1176.0                         730                   716
# 1188.0                         720                   709
#
# intervention  EG_Ceramide_S1P_1_33  EG_GAP_RAS_1_11  ...  \
# 0.0                           1500             1500  ...
# 12.0                          1501             1501  ...
# 24.0                          1503             1501  ...
# 36.0                          1504             1504  ...
# 48.0                          1505             1506  ...
# ...                            ...              ...  ...
# 1140.0                         778             1592  ...
# 1152.0                         758             1594  ...
# 1164.0                         745             1595  ...
# 1176.0                         736             1596  ...
# 1188.0                         724             1597  ...
#
# intervention  SM_pro_Ceramidepro_RAS_33  SM_pro_TBETpro_Ceramidepro_ERK_11  \
# 0.0                                1500                               1500
# 12.0                               1501                               1499
# 24.0                               1504                               1499
# 36.0                               1504                               1500
# 48.0                               1505                               1501
# ...                                 ...                                ...
# 1140.0                              649                               1662
# 1152.0                              640                               1662
# 1164.0                              635                               1664
# 1176.0                              630                               1668
# 1188.0                              623                               1669
#
# intervention  SM_pro_TBETpro_Ceramidepro_ERK_12  \
# 0.0                                        1500
# 12.0                                       1503
# 24.0                                       1504
# 36.0                                       1504
# 48.0                                       1507
# ...                                         ...
# 1140.0                                     1684
# 1152.0                                     1686
# 1164.0                                     1688
# 1176.0                                     1691
# 1188.0                                     1694
#
# intervention  SM_pro_TBETpro_Ceramidepro_ERK_13  \
# 0.0                                        1500
# 12.0                                       1501
# 24.0                                       1502
# 36.0                                       1504
# 48.0                                       1506
# ...                                         ...
# 1140.0                                     1686
# 1152.0                                     1687
# 1164.0                                     1689
# 1176.0                                     1691
# 1188.0                                     1694
#
# intervention  SM_pro_TBETpro_Ceramidepro_ERK_21  \
# 0.0                                        1500
# 12.0                                       1501
# 24.0                                       1503
# 36.0                                       1504
# 48.0                                       1507
# ...                                         ...
# 1140.0                                     1682
# 1152.0                                     1686
# 1164.0                                     1687
# 1176.0                                     1689
# 1188.0                                     1694
#
# intervention  SM_pro_TBETpro_Ceramidepro_ERK_22  \
# 0.0                                        1500
# 12.0                                       1502
# 24.0                                       1502
# 36.0                                       1506
# 48.0                                       1508
# ...                                         ...
# 1140.0                                     1651
# 1152.0                                     1653
# 1164.0                                     1655
# 1176.0                                     1656
# 1188.0                                     1660
#
# intervention  SM_pro_TBETpro_Ceramidepro_ERK_23  \
# 0.0                                        1500
# 12.0                                       1502
# 24.0                                       1503
# 36.0                                       1505
# 48.0                                       1506
# ...                                         ...
# 1140.0                                     1687
# 1152.0                                     1687
# 1164.0                                     1690
# 1176.0                                     1690
# 1188.0                                     1690
#
# intervention  SM_pro_TBETpro_Ceramidepro_ERK_31  \
# 0.0                                        1500
# 12.0                                       1498
# 24.0                                       1499
# 36.0                                       1500
# 48.0                                       1504
# ...                                         ...
# 1140.0                                     1693
# 1152.0                                     1695
# 1164.0                                     1698
# 1176.0                                     1698
# 1188.0                                     1699
#
# intervention  SM_pro_TBETpro_Ceramidepro_ERK_32  \
# 0.0                                        1500
# 12.0                                       1498
# 24.0                                       1503
# 36.0                                       1503
# 48.0                                       1503
# ...                                         ...
# 1140.0                                     1678
# 1152.0                                     1680
# 1164.0                                     1680
# 1176.0                                     1682
# 1188.0                                     1683
#
# intervention  SM_pro_TBETpro_Ceramidepro_ERK_33
# 0.0                                        1500
# 12.0                                       1501
# 24.0                                       1503
# 36.0                                       1504
# 48.0                                       1504
# ...                                         ...
# 1140.0                                     1641
# 1152.0                                     1642
# 1164.0                                     1643
# 1176.0                                     1646
# 1188.0                                     1647
#
# [100 rows x 252 columns]

# %% [markdown]
# Now we have something to plot! Lets chck them out!!

# %%
for intervention in df_transpose:
    # intervention_df = df[df.intervention == intervention]
    plt.plot(df_transpose.index, df_transpose[intervention])

# %% [markdown]
# Get the mean across replicates

# %% [markdown]
# ### Figure out this code
#
# Can it be simplified? There miaght be some more to learn here - as well as simplify.

# %%
# Simplified function to average every three columns as replicates
def average_replicates_every_three(df):
    # Initialize an empty DataFrame for the averaged results
    result = pd.DataFrame()

    # Process columns in steps of three
    for i in range(0, len(df.columns), 3):
        # The base name for the averaged column can be derived from the first of each three columns,
        # removing the last digit and the underscore immediately preceding it.
        # This needs fixed - jsut need to remove the last digit
        base_name = df.columns[i][:-1]  # Remove only the last character (replicate number)
        # print(base_name)
        
        # Select the three replicate columns
        replicate_cols = df.iloc[:, i:i+3]
        # print(replicate_cols)
        
        # Calculate the average of these columns
        result[base_name] = replicate_cols.mean(axis=1)
    
    return result

# Apply the function
df_avg = average_replicates_every_three(df_transpose)

# Now df_avg contains the averaged columns
print(df_avg.shape)
# Out:
# (661, 84)

# %%
df_avg.tail()
# Out:
#         EG_Ceramide_S1P_1_1  EG_Ceramide_S1P_1_2  EG_Ceramide_S1P_1_3  \
# 7872.0           343.000000                  2.0             0.666667
# 7884.0           343.000000                  2.0             0.666667
# 7896.0           342.666667                  2.0             0.666667
# 7908.0           342.000000                  2.0             0.666667
# 7920.0           341.333333                  2.0             0.333333
#
#         EG_GAP_RAS_1_1  EG_GAP_RAS_1_2  EG_GAP_RAS_1_3  EG_IL15_GAP_0_1  \
# 7872.0     2406.666667      533.000000       24.666667      2443.000000
# 7884.0     2407.333333      531.000000       24.333333      2444.333333
# 7896.0     2409.666667      526.666667       24.333333      2444.666667
# 7908.0     2408.666667      523.000000       24.333333      2444.666667
# 7920.0     2408.000000      520.000000       24.000000      2443.666667
#
#         EG_IL15_GAP_0_2  EG_IL15_GAP_0_3  EG_IL2RBT_IL2RB_0_1  ...  \
# 7872.0       590.000000        27.333333          2431.333333  ...
# 7884.0       586.333333        27.000000          2435.000000  ...
# 7896.0       582.333333        27.000000          2437.666667  ...
# 7908.0       579.666667        26.333333          2441.666667  ...
# 7920.0       575.000000        26.333333          2445.000000  ...
#
#         SM_pro_Ceramidepro_PI3Kpro_ERK_3  SM_pro_Ceramidepro_PI3Kpro_MEK_1  \
# 7872.0                               0.0                        327.333333
# 7884.0                               0.0                        325.666667
# 7896.0                               0.0                        325.000000
# 7908.0                               0.0                        324.000000
# 7920.0                               0.0                        322.666667
#
#         SM_pro_Ceramidepro_PI3Kpro_MEK_2  SM_pro_Ceramidepro_PI3Kpro_MEK_3  \
# 7872.0                               0.0                               2.0
# 7884.0                               0.0                               2.0
# 7896.0                               0.0                               2.0
# 7908.0                               0.0                               2.0
# 7920.0                               0.0                               2.0
#
#         SM_pro_Ceramidepro_RAS_1  SM_pro_Ceramidepro_RAS_2  \
# 7872.0                348.000000                       0.0
# 7884.0                347.333333                       0.0
# 7896.0                347.000000                       0.0
# 7908.0                346.000000                       0.0
# 7920.0                345.333333                       0.0
#
#         SM_pro_Ceramidepro_RAS_3  SM_pro_TBETpro_Ceramidepro_ERK_1  \
# 7872.0                  0.666667                        518.333333
# 7884.0                  0.666667                        518.333333
# 7896.0                  0.666667                        517.000000
# 7908.0                  0.666667                        515.666667
# 7920.0                  0.666667                        514.000000
#
#         SM_pro_TBETpro_Ceramidepro_ERK_2  SM_pro_TBETpro_Ceramidepro_ERK_3
# 7872.0                          5.000000                        343.333333
# 7884.0                          5.000000                        341.333333
# 7896.0                          5.000000                        338.666667
# 7908.0                          4.333333                        337.666667
# 7920.0                          4.333333                        336.666667
#
# [5 rows x 84 columns]

# %%
for intervention in df_avg:
    # intervention_df = df[df.intervention == intervention]
    plt.plot(df_avg.index, df_avg[intervention])

# %%
short_decay = {}
medium_decay = {}
long_decay = {}

for column in df_avg.columns:
    decay_digit = column.split('_',10)[-1] # will get the 1, 2, or 3 for decay constant
    # print(decay_digit)
    if decay_digit == '1':
        short_decay[column] = df_avg[column]
    if decay_digit == '2':
        medium_decay[column] = df_avg[column]
    if decay_digit == '3':
        long_decay[column] = df_avg[column]


df_short_decay = pd.DataFrame(short_decay)
df_medium_decay = pd.DataFrame(medium_decay)
df_long_decay = pd.DataFrame(long_decay)
df_long_decay.head()
# Out:
#       EG_Ceramide_S1P_1_3  EG_GAP_RAS_1_3  EG_IL15_GAP_0_3  \
# 0.0           1500.000000     1500.000000      1500.000000
# 12.0          1501.000000     1500.333333      1501.000000
# 24.0          1502.333333     1501.333333      1502.333333
# 36.0          1503.666667     1502.000000      1503.000000
# 48.0          1505.000000     1504.333333      1504.333333
#
#       EG_IL2RBT_IL2RB_0_3  EG_IL2RB_MCL1_0_3  EG_JAK_STAT3_0_3  \
# 0.0           1500.000000        1500.000000       1500.000000
# 12.0          1501.000000        1500.000000       1501.666667
# 24.0          1502.333333        1501.333333       1503.333333
# 36.0          1504.333333        1503.000000       1505.666667
# 48.0          1506.333333        1504.333333       1507.666667
#
#       EG_MCL1_BID_0_3  EG_PDGFR_SPHK1_0_3  EG_PI3K_ERK_0_3  EG_RAS_MEK_0_3  \
# 0.0       1500.000000         1500.000000      1500.000000     1500.000000
# 12.0      1500.666667         1501.333333      1501.666667     1500.333333
# 24.0      1501.333333         1502.333333      1502.333333     1501.333333
# 36.0      1503.333333         1503.666667      1504.333333     1503.000000
# 48.0      1504.000000         1506.333333      1505.666667     1504.333333
#
#       ...  SM_anti_PDGFR_3  SM_anti_S1P_3  SM_anti_SPHK1_3  \
# 0.0   ...      1500.000000    1500.000000      1500.000000
# 12.0  ...      1499.666667    1500.333333      1501.333333
# 24.0  ...      1500.000000    1501.333333      1502.333333
# 36.0  ...      1502.000000    1503.333333      1504.666667
# 48.0  ...      1503.000000    1505.333333      1507.333333
#
#       SM_pro_Ceramidepro_GRB2_3  SM_pro_Ceramidepro_IL2RBT_3  \
# 0.0                 1500.000000                  1500.000000
# 12.0                1500.000000                  1500.333333
# 24.0                1501.666667                  1501.333333
# 36.0                1504.333333                  1502.000000
# 48.0                1504.333333                  1504.000000
#
#       SM_pro_Ceramidepro_IL2RB_3  SM_pro_Ceramidepro_PI3Kpro_ERK_3  \
# 0.0                  1500.000000                       1500.000000
# 12.0                 1500.666667                       1500.666667
# 24.0                 1503.000000                       1501.666667
# 36.0                 1505.000000                       1501.666667
# 48.0                 1506.333333                       1502.666667
#
#       SM_pro_Ceramidepro_PI3Kpro_MEK_3  SM_pro_Ceramidepro_RAS_3  \
# 0.0                        1500.000000               1500.000000
# 12.0                       1500.666667               1500.000000
# 24.0                       1503.000000               1502.666667
# 36.0                       1503.666667               1503.333333
# 48.0                       1504.000000               1504.000000
#
#       SM_pro_TBETpro_Ceramidepro_ERK_3
# 0.0                        1500.000000
# 12.0                       1499.000000
# 24.0                       1501.666667
# 36.0                       1502.333333
# 48.0                       1503.666667
#
# [5 rows x 28 columns]

# %% [markdown]
# What I really want next is to be able to select bsed on the different attributes. So I'll transpose it and split the name up and then can sort baed on that.

# %%
df_avg_transpose = df_avg.transpose()
df_avg_transpose.head()
# Out:
#                         0.0         12.0         24.0         36.0  \
# EG_Ceramide_S1P_1_1  1500.0  1500.666667  1502.000000  1502.333333
# EG_Ceramide_S1P_1_2  1500.0  1502.000000  1503.333333  1504.666667
# EG_Ceramide_S1P_1_3  1500.0  1501.000000  1502.333333  1503.666667
# EG_GAP_RAS_1_1       1500.0  1500.666667  1501.333333  1503.333333
# EG_GAP_RAS_1_2       1500.0  1500.666667  1502.000000  1502.000000
#
#                             48.0         60.0         72.0         84.0  \
# EG_Ceramide_S1P_1_1  1503.333333  1505.333333  1508.000000  1509.000000
# EG_Ceramide_S1P_1_2  1505.666667  1509.333333  1510.666667  1513.000000
# EG_Ceramide_S1P_1_3  1505.000000  1506.333333  1507.333333  1508.333333
# EG_GAP_RAS_1_1       1505.000000  1506.333333  1508.000000  1509.666667
# EG_GAP_RAS_1_2       1504.666667  1505.666667  1506.000000  1508.333333
#
#                             96.0        108.0  ...       7812.0       7824.0  \
# EG_Ceramide_S1P_1_1  1510.666667  1511.666667  ...   349.000000   347.000000
# EG_Ceramide_S1P_1_2  1513.666667  1515.000000  ...     2.000000     2.000000
# EG_Ceramide_S1P_1_3  1511.666667  1515.333333  ...     0.666667     0.666667
# EG_GAP_RAS_1_1       1511.666667  1512.666667  ...  2407.666667  2406.000000
# EG_GAP_RAS_1_2       1510.000000  1512.333333  ...   549.333333   546.666667
#
#                           7836.0       7848.0       7860.0       7872.0  \
# EG_Ceramide_S1P_1_1   345.000000   344.000000   343.000000   343.000000
# EG_Ceramide_S1P_1_2     2.000000     2.000000     2.000000     2.000000
# EG_Ceramide_S1P_1_3     0.666667     0.666667     0.666667     0.666667
# EG_GAP_RAS_1_1       2406.666667  2408.333333  2407.000000  2406.666667
# EG_GAP_RAS_1_2        541.666667   538.666667   535.333333   533.000000
#
#                           7884.0       7896.0       7908.0       7920.0
# EG_Ceramide_S1P_1_1   343.000000   342.666667   342.000000   341.333333
# EG_Ceramide_S1P_1_2     2.000000     2.000000     2.000000     2.000000
# EG_Ceramide_S1P_1_3     0.666667     0.666667     0.666667     0.333333
# EG_GAP_RAS_1_1       2407.333333  2409.666667  2408.666667  2408.000000
# EG_GAP_RAS_1_2        531.000000   526.666667   523.000000   520.000000
#
# [5 rows x 661 columns]

# %%
# I could use the index and make a new data from splitting it, then concatenate the dataframes (but that coudl be weird)

df_categories = pd.DataFrame(index=df_avg_transpose.index)

for index in df_avg_transpose.index:
    split_index = index.split('_', 10)
    df_categories.loc[index, 'algorithm'] = split_index[0]
    df_categories.loc[index, 'decay'] = split_index[-1]
    # df_temp.loc[index, 'type'] = split_index[-2] # this would involve string matching to really do right (pro = 1, anti=0)


df_categories
# Out:
#                                  algorithm decay
# EG_Ceramide_S1P_1_1                     EG     1
# EG_Ceramide_S1P_1_2                     EG     2
# EG_Ceramide_S1P_1_3                     EG     3
# EG_GAP_RAS_1_1                          EG     1
# EG_GAP_RAS_1_2                          EG     2
# ...                                    ...   ...
# SM_pro_Ceramidepro_RAS_2                SM     2
# SM_pro_Ceramidepro_RAS_3                SM     3
# SM_pro_TBETpro_Ceramidepro_ERK_1        SM     1
# SM_pro_TBETpro_Ceramidepro_ERK_2        SM     2
# SM_pro_TBETpro_Ceramidepro_ERK_3        SM     3
#
# [84 rows x 2 columns]

# %%
df_categories_short = df_categories[df_categories.decay == '1'].transpose()

df_categories_medium = df_categories[df_categories.decay == '2'].transpose()

df_categories_long = df_categories[df_categories.decay == '3'].transpose()

# %% [markdown]
# Now we can get whatever we want from these categories.
#
# I'll have to remember how to use seaborn some time ...
# And what I really need are lists of the columns I care about. Maybe even make a data frame of those - then I can sort by row, taking the index - then get whatever I want out of the main df ...
#
# so a sub df with intervention as index, split the index out by type, name, decay (and replicate?) (maybe two DFs - one fulll one and one mean)
#
# Then I can pull up whatever we want
#
# And the pd plotters is fast.
#
# and of course, I can pull out whatever I wnat also by splitting
#
#     if intervention.split('_',10)[0] == 'EG' and intervention.split('_')[-2] == '1':
#         plt.plot(df_short_decay.index, df_short_decay[intervention])

# %%
for intervention in df_categories_long:
    plt.plot(df_avg.index, df_avg[intervention])

# %%
for intervention in df_categories_short:
    if intervention.split('_',10)[0] == 'EG': # would like to get this not having to split the string but not shure how to do that
        plt.plot(df_avg.index, df_avg[intervention])

# %%
for intervention in df_categories_medium:
    if intervention.split('_',10)[0] == 'EG':
        plt.plot(df_avg.index, df_avg[intervention], label=intervention)

# %%
for intervention in df_categories_long:
    if intervention.split('_',10)[0] == 'EG':
        plt.plot(df_avg.index, df_avg[intervention], label=intervention)

# %% [markdown]
# ## Space!!!

# %%
df_space = pd.read_csv('../dataframes/aggregated_live_cells_spatial.csv', index_col=0)
print(df_space.shape)
df_space.head()
# Out:
# (28, 361)
#                        0.0  12.0  24.0  36.0  48.0  60.0  72.0  84.0  96.0  \
# intervention
# EG_Ceramide_S1P_1_11  1344  1343  1344  1346  1348  1348  1349  1350  1350
# EG_GAP_RAS_1_11       1344  1342  1343  1343  1344  1347  1348  1349  1350
# EG_IL15_GAP_0_11      1344  1343  1344  1344  1345  1346  1347  1348  1349
# EG_IL2RBT_IL2RB_0_11  1344  1344  1344  1346  1350  1352  1354  1355  1358
# EG_IL2RB_MCL1_0_11    1344  1345  1345  1345  1346  1347  1347  1350  1352
#
#                       108.0  ...  4212.0  4224.0  4236.0  4248.0  4260.0  \
# intervention                 ...
# EG_Ceramide_S1P_1_11   1352  ...     823     823     824     822     822
# EG_GAP_RAS_1_11        1351  ...     821     821     820     820     820
# EG_IL15_GAP_0_11       1350  ...     822     822     822     821     821
# EG_IL2RBT_IL2RB_0_11   1359  ...     816     816     816     816     815
# EG_IL2RB_MCL1_0_11     1354  ...     824     823     823     825     825
#
#                       4272.0  4284.0  4296.0  4308.0  4320.0
# intervention
# EG_Ceramide_S1P_1_11     823     822     824     824     823
# EG_GAP_RAS_1_11          822     823     823     824     824
# EG_IL15_GAP_0_11         821     823     822     822     823
# EG_IL2RBT_IL2RB_0_11     815     815     815     814     813
# EG_IL2RB_MCL1_0_11       825     826     826     826     827
#
# [5 rows x 361 columns]

# %%
df_space_transpose = df_space.transpose()
print(df_space_transpose.shape)
df_space_transpose.head()
# Out:
# (361, 28)
# intervention  EG_Ceramide_S1P_1_11  EG_GAP_RAS_1_11  EG_IL15_GAP_0_11  \
# 0.0                           1344             1344              1344
# 12.0                          1343             1342              1343
# 24.0                          1344             1343              1344
# 36.0                          1346             1343              1344
# 48.0                          1348             1344              1345
#
# intervention  EG_IL2RBT_IL2RB_0_11  EG_IL2RB_MCL1_0_11  EG_JAK_STAT3_0_11  \
# 0.0                           1344                1344               1344
# 12.0                          1344                1345               1344
# 24.0                          1344                1345               1351
# 36.0                          1346                1345               1353
# 48.0                          1350                1346               1354
#
# intervention  EG_MCL1_BID_0_11  EG_PDGFR_SPHK1_0_11  EG_PI3K_ERK_0_11  \
# 0.0                       1344                 1344              1344
# 12.0                      1344                 1345              1342
# 24.0                      1347                 1347              1342
# 36.0                      1350                 1349              1344
# 48.0                      1352                 1351              1345
#
# intervention  EG_RAS_MEK_0_11  ...  SM_anti_PDGFR_11  SM_anti_S1P_11  \
# 0.0                      1344  ...              1344            1344
# 12.0                     1346  ...              1347            1347
# 24.0                     1346  ...              1350            1347
# 36.0                     1348  ...              1350            1352
# 48.0                     1348  ...              1353            1355
#
# intervention  SM_anti_SPHK1_11  SM_pro_Ceramidepro_GRB2_11  \
# 0.0                       1344                        1344
# 12.0                      1346                        1344
# 24.0                      1347                        1345
# 36.0                      1348                        1345
# 48.0                      1348                        1345
#
# intervention  SM_pro_Ceramidepro_IL2RBT_11  SM_pro_Ceramidepro_IL2RB_11  \
# 0.0                                   1344                         1344
# 12.0                                  1345                         1346
# 24.0                                  1346                         1347
# 36.0                                  1346                         1347
# 48.0                                  1347                         1347
#
# intervention  SM_pro_Ceramidepro_PI3Kpro_ERK_11  \
# 0.0                                        1344
# 12.0                                       1345
# 24.0                                       1346
# 36.0                                       1346
# 48.0                                       1347
#
# intervention  SM_pro_Ceramidepro_PI3Kpro_MEK_11  SM_pro_Ceramidepro_RAS_11  \
# 0.0                                        1344                       1344
# 12.0                                       1350                       1344
# 24.0                                       1350                       1345
# 36.0                                       1352                       1345
# 48.0                                       1355                       1347
#
# intervention  SM_pro_TBETpro_Ceramidepro_ERK_11
# 0.0                                        1344
# 12.0                                       1345
# 24.0                                       1347
# 36.0                                       1349
# 48.0                                       1351
#
# [5 rows x 28 columns]

# %%
for intervention in df_space_transpose:
    # intervention_df = df[df.intervention == intervention]
    plt.plot(df_space_transpose.index, df_space_transpose[intervention])

# %%
df_categories_space = pd.DataFrame(index=df_space.index)

for index in df_categories_space.index:
    split_index = index.split('_', 10)
    df_categories_space.loc[index, 'algorithm'] = split_index[0]
    # df_categories_space.loc[index, 'decay'] = split_index[-1]
    # df_temp.loc[index, 'type'] = split_index[-2] # this would involve string matching to really do right (pro = 1, anti=0)


df_categories_space
# Out:
#                                   algorithm
# intervention
# EG_Ceramide_S1P_1_11                     EG
# EG_GAP_RAS_1_11                          EG
# EG_IL15_GAP_0_11                         EG
# EG_IL2RBT_IL2RB_0_11                     EG
# EG_IL2RB_MCL1_0_11                       EG
# EG_JAK_STAT3_0_11                        EG
# EG_MCL1_BID_0_11                         EG
# EG_PDGFR_SPHK1_0_11                      EG
# EG_PI3K_ERK_0_11                         EG
# EG_RAS_MEK_0_11                          EG
# EG_S1P_PDGFR_0_11                        EG
# IB_anti_sFas_11                          IB
# IB_pro_Ceramide_11                       IB
# IB_pro_DISC_11                           IB
# IB_pro_FasL_11                           IB
# IB_pro_FasT_11                           IB
# IB_pro_Fas_11                            IB
# IB_pro_TBET_11                           IB
# SM_anti_PDGFR_11                         SM
# SM_anti_S1P_11                           SM
# SM_anti_SPHK1_11                         SM
# SM_pro_Ceramidepro_GRB2_11               SM
# SM_pro_Ceramidepro_IL2RBT_11             SM
# SM_pro_Ceramidepro_IL2RB_11              SM
# SM_pro_Ceramidepro_PI3Kpro_ERK_11        SM
# SM_pro_Ceramidepro_PI3Kpro_MEK_11        SM
# SM_pro_Ceramidepro_RAS_11                SM
# SM_pro_TBETpro_Ceramidepro_ERK_11        SM

# %%
for intervention in df_categories_space[df_categories_space.algorithm == 'IB'].index:
    plt.plot(df_space_transpose.index, df_space_transpose[intervention])

# %%
for intervention in df_categories_space[df_categories_space.algorithm == 'EG'].index:
    plt.plot(df_space_transpose.index, df_space_transpose[intervention])

# %%
for intervention in df_categories_space[df_categories_space.algorithm == 'SM'].index:
    plt.plot(df_space_transpose.index, df_space_transpose[intervention], label=intervention)

plt.legend(loc='upper right')

# %% [markdown]
# ## Space!!! (with PKPD!!!)
#
# Thats close enough!!!

# %%
df_space = pd.read_csv('../dataframes/aggregated_live_cells_spatial_new_model.csv', index_col=0)
print(df_space.shape)
df_space.head()
# Out:
# (28, 361)
#                        0.0  12.0  24.0  36.0  48.0  60.0  72.0  84.0  96.0  \
# intervention
# EG_Ceramide_S1P_1_11  1344  1343  1345  1348  1350  1351  1352  1354  1355
# EG_GAP_RAS_1_11       1344  1345  1346  1347  1348  1350  1351  1353  1354
# EG_IL15_GAP_0_11      1344  1345  1345  1346  1347  1348  1350  1351  1352
# EG_IL2RBT_IL2RB_0_11  1344  1344  1347  1348  1349  1352  1353  1353  1355
# EG_IL2RB_MCL1_0_11    1344  1344  1344  1348  1348  1348  1351  1352  1352
#
#                       108.0  ...  4212.0  4224.0  4236.0  4248.0  4260.0  \
# intervention                 ...
# EG_Ceramide_S1P_1_11   1357  ...     817     817     818     818     819
# EG_GAP_RAS_1_11        1355  ...     836     836     836     837     837
# EG_IL15_GAP_0_11       1352  ...     834     834     834     834     835
# EG_IL2RBT_IL2RB_0_11   1355  ...     809     809     810     810     811
# EG_IL2RB_MCL1_0_11     1350  ...     818     818     818     821     822
#
#                       4272.0  4284.0  4296.0  4308.0  4320.0
# intervention
# EG_Ceramide_S1P_1_11     820     818     818     819     818
# EG_GAP_RAS_1_11          837     837     837     837     838
# EG_IL15_GAP_0_11         835     835     836     836     835
# EG_IL2RBT_IL2RB_0_11     811     812     812     813     813
# EG_IL2RB_MCL1_0_11       822     822     821     821     820
#
# [5 rows x 361 columns]

# %%
df_space_transpose = df_space.transpose()
print(df_space_transpose.shape)
df_space_transpose.head()
# Out:
# (361, 28)
# intervention  EG_Ceramide_S1P_1_11  EG_GAP_RAS_1_11  EG_IL15_GAP_0_11  \
# 0.0                           1344             1344              1344
# 12.0                          1343             1345              1345
# 24.0                          1345             1346              1345
# 36.0                          1348             1347              1346
# 48.0                          1350             1348              1347
#
# intervention  EG_IL2RBT_IL2RB_0_11  EG_IL2RB_MCL1_0_11  EG_JAK_STAT3_0_11  \
# 0.0                           1344                1344               1344
# 12.0                          1344                1344               1347
# 24.0                          1347                1344               1348
# 36.0                          1348                1348               1351
# 48.0                          1349                1348               1352
#
# intervention  EG_MCL1_BID_0_11  EG_PDGFR_SPHK1_0_11  EG_PI3K_ERK_0_11  \
# 0.0                       1344                 1344              1344
# 12.0                      1345                 1343              1346
# 24.0                      1347                 1344              1348
# 36.0                      1347                 1345              1349
# 48.0                      1347                 1346              1350
#
# intervention  EG_RAS_MEK_0_11  ...  SM_anti_PDGFR_11  SM_anti_S1P_11  \
# 0.0                      1344  ...              1344            1344
# 12.0                     1345  ...              1346            1344
# 24.0                     1345  ...              1347            1344
# 36.0                     1347  ...              1347            1345
# 48.0                     1348  ...              1348            1346
#
# intervention  SM_anti_SPHK1_11  SM_pro_Ceramidepro_GRB2_11  \
# 0.0                       1344                        1344
# 12.0                      1344                        1345
# 24.0                      1344                        1349
# 36.0                      1346                        1352
# 48.0                      1348                        1356
#
# intervention  SM_pro_Ceramidepro_IL2RBT_11  SM_pro_Ceramidepro_IL2RB_11  \
# 0.0                                   1344                         1344
# 12.0                                  1344                         1348
# 24.0                                  1346                         1348
# 36.0                                  1346                         1349
# 48.0                                  1346                         1349
#
# intervention  SM_pro_Ceramidepro_PI3Kpro_ERK_11  \
# 0.0                                        1344
# 12.0                                       1345
# 24.0                                       1351
# 36.0                                       1351
# 48.0                                       1351
#
# intervention  SM_pro_Ceramidepro_PI3Kpro_MEK_11  SM_pro_Ceramidepro_RAS_11  \
# 0.0                                        1344                       1344
# 12.0                                       1343                       1342
# 24.0                                       1344                       1344
# 36.0                                       1343                       1345
# 48.0                                       1343                       1346
#
# intervention  SM_pro_TBETpro_Ceramidepro_ERK_11
# 0.0                                        1344
# 12.0                                       1344
# 24.0                                       1345
# 36.0                                       1345
# 48.0                                       1345
#
# [5 rows x 28 columns]

# %%
for intervention in df_space_transpose:
    # intervention_df = df[df.intervention == intervention]
    plt.plot(df_space_transpose.index, df_space_transpose[intervention])

# %%
df_categories_space = pd.DataFrame(index=df_space.index)

for index in df_categories_space.index:
    split_index = index.split('_', 10)
    df_categories_space.loc[index, 'algorithm'] = split_index[0]
    # df_categories_space.loc[index, 'decay'] = split_index[-1]
    # df_temp.loc[index, 'type'] = split_index[-2] # this would involve string matching to really do right (pro = 1, anti=0)


df_categories_space
# Out:
#                                   algorithm
# intervention
# EG_Ceramide_S1P_1_11                     EG
# EG_GAP_RAS_1_11                          EG
# EG_IL15_GAP_0_11                         EG
# EG_IL2RBT_IL2RB_0_11                     EG
# EG_IL2RB_MCL1_0_11                       EG
# EG_JAK_STAT3_0_11                        EG
# EG_MCL1_BID_0_11                         EG
# EG_PDGFR_SPHK1_0_11                      EG
# EG_PI3K_ERK_0_11                         EG
# EG_RAS_MEK_0_11                          EG
# EG_S1P_PDGFR_0_11                        EG
# IB_anti_sFas_11                          IB
# IB_pro_Ceramide_11                       IB
# IB_pro_DISC_11                           IB
# IB_pro_FasL_11                           IB
# IB_pro_FasT_11                           IB
# IB_pro_Fas_11                            IB
# IB_pro_TBET_11                           IB
# SM_anti_PDGFR_11                         SM
# SM_anti_S1P_11                           SM
# SM_anti_SPHK1_11                         SM
# SM_pro_Ceramidepro_GRB2_11               SM
# SM_pro_Ceramidepro_IL2RBT_11             SM
# SM_pro_Ceramidepro_IL2RB_11              SM
# SM_pro_Ceramidepro_PI3Kpro_ERK_11        SM
# SM_pro_Ceramidepro_PI3Kpro_MEK_11        SM
# SM_pro_Ceramidepro_RAS_11                SM
# SM_pro_TBETpro_Ceramidepro_ERK_11        SM

# %%
for intervention in df_categories_space[df_categories_space.algorithm == 'IB'].index:
    plt.plot(df_space_transpose.index, df_space_transpose[intervention])

# %%
for intervention in df_categories_space[df_categories_space.algorithm == 'EG'].index:
    plt.plot(df_space_transpose.index, df_space_transpose[intervention])

# %%
for intervention in df_categories_space[df_categories_space.algorithm == 'SM'].index:
    plt.plot(df_space_transpose.index, df_space_transpose[intervention], label=intervention)

plt.legend(loc='upper right')
